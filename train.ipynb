# %%
import torch

if torch.cuda.is_available():
    print("Available GPUs:")
    for i in range(torch.cuda.device_count()):
        print(f"{i}: {torch.cuda.get_device_name(i)}")
else:
    print("No GPU available.")
# Out:
# Available GPUs:
# 0: Tesla T4

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

def main():
    model = YOLO("/Users/jaydeep/Desktop/Personal_project/models/yolo11s.pt") 
    model.info()

    results = model.train(
        data="/content/data.yaml",
        epochs=80,           # Number of epochs
        imgsz=640,           # Image size (640x640)
        batch=16,            # Batch size
        fliplr=0.5,          # 50% chance of horizontal flip
        flipud=0.0,          # No vertical flip
        degrees=5,           # Random rotation ±5 degrees
        shear=10,            # Shear ±10 degrees
        name="yolo11s_custom_train",  # Optional: custom run name
        patience=50,         # Early stopping patience (optional)
        device=0           # Auto-detect GPU/CPU; use device=0 for specific GPU
    )

    print(results)

if __name__ == "__main__":
    main()
# Out:
# YOLO11s summary: 181 layers, 9,458,752 parameters, 0 gradients, 21.7 GFLOPs
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
import shutil

# Path to your folder
folder_path = "/content/runs"

# Create a zip file
shutil.make_archive("yolo_train_results", 'zip', folder_path)

# Download the zip
files.download("yolo_train_results.zip")

# %%
# install required packages first:
# pip install ultralytics opencv-python

from ultralytics import YOLO
import cv2

# Load the YOLOv8 model (you can use 'yolov8n.pt', 'yolov8s.pt', etc.)
model = YOLO('best.pt')  # nano version, fast and lightweight

# Open video file or webcam
video_path = "/Users/jaydeep/Desktop/Personal_project/data/videos/2024-07-12_17-05-13_17-13-01.mp4"  # Change to 0 for webcam
cap = cv2.VideoCapture(video_path)

# Get video properties for output
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define output video writer (optional)
output_path = "output_video.mp4"
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO inference on the frame
    results = model(frame, classes=[1,2,3])

    # Draw results on the frame
    annotated_frame = results[0].plot()

    # Write the frame to output video
    out.write(annotated_frame)

    # Display the frame (optional)
    # cv2.imshow('YOLOv8 Video', annotated_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processing complete. Output saved to {output_path}")
# Out:
# 0: 384x640 1 Normal wrist, 2 wrist with products, 91.0ms
# Speed: 7.9ms preprocess, 91.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Normal wrists, 1 wrist with product, 74.4ms
# Speed: 2.4ms preprocess, 74.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Normal wrists, 71.7ms
# Speed: 1.5ms preprocess, 71.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Normal wrists, 68.8ms
# Speed: 1.6ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Normal wrist, 67.5ms
# Speed: 1.6ms preprocess, 67.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Normal wrists, 65.4ms
# Speed: 1.8ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Normal wrist, 66.9ms
# ...

# %%
# %which python
# Out:
# UsageError: Line magic function `%` not found.

# %%
import sys
print(sys.executable)
# Out:
# /Users/jaydeep/Desktop/Personal_project/myenv/bin/python
